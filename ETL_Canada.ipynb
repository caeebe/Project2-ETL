# %%
import pandas as pd
import numpy as np

# %%
canadafile = "CanadaCSV/canadalimited.csv"

# %%
canada_df = pd.read_csv(canadafile, encoding="utf-8")
# Out:
# C:\Users\Iam\anaconda\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (1,2,5,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
canada_df.head()
# Out:
#    C_YEAR C_MNTH C_WDAY C_HOUR  C_SEV C_VEHS C_CONF C_RCFG C_WTHR C_RSUR  \
# 0    2011      1      1     10      2      1     02     03      1      3
# 1    2011      1      1     12      2      1     04     UU      1      5
# 2    2011      1      1     00      2      1     03     UU      7      3
# 3    2011      1      1     17      2      2     21     UU      1      1
# 4    2011      1      1     17      2      2     21     UU      1      1
#
#    ...   V_ID V_TYPE V_YEAR P_ID P_SEX P_AGE P_PSN P_ISEV P_SAFE P_USER
# 0  ...      1     01   UUUU   01     M    75    11      2     NN      1
# 1  ...      1     01   UUUU   01     F    21    11      2     02      1
# 2  ...      1     01   UUUU   01     F    34    11      2     02      1
# 3  ...      1     01   UUUU   01     F    50    11      2     02      1
# 4  ...      2     01   UUUU   01     M    63    11      1     NN      1
#
# [5 rows x 22 columns]

# %%
list(canada_df.columns.values)
# Out:
# ['C_YEAR',
#  'C_MNTH',
#  'C_WDAY',
#  'C_HOUR',
#  'C_SEV',
#  'C_VEHS',
#  'C_CONF',
#  'C_RCFG',
#  'C_WTHR',
#  'C_RSUR',
#  'C_RALN',
#  'C_TRAF',
#  'V_ID',
#  'V_TYPE',
#  'V_YEAR',
#  'P_ID',
#  'P_SEX',
#  'P_AGE',
#  'P_PSN',
#  'P_ISEV',
#  'P_SAFE',
#  'P_USER']

# %%
canada_df.drop(columns=['C_SEV', 'C_VEHS', 'C_CONF', 'C_RCFG', 'C_RALN', 'C_TRAF', 'V_ID', 'V_YEAR', 'P_ID', 'P_SEX', 'P_AGE', 'P_PSN', 'P_USER'], inplace=True)

# %%
canada_df['V_TYPE'] = canada_df['V_TYPE'].replace({'01': 1, '05': 0, '06': 0, '07': 0, '08': 0, '09': 0, '10': 0, '11': 0, '14': 0, '16': 0, '17': 0, '18': 0, '19': 0, '20': 0, '21': 0, '22': 0, '23': 0, 'NN': 0, 'QQ': 0, 'UU': 0, 'XX': 0})

# %%
canada_df['P_ISEV'] = canada_df['P_ISEV'].replace({'3': 1, '2': 0, '1': 0, 'N': 0, 'U': 0, 'X': 0})

# %%
canada_df['P_SAFE'] = canada_df['P_SAFE'].replace({'01': 2, '02': 0, '09': 0, '10': 0, '11': 0, '12': 0, '13': 0, 'NN': 1, 'QQ': 1, 'UU': 1, 'XX': 1})

# %%
canada_df['P_SAFE'].unique()
# Out:
# array([1, 0, 2], dtype=int64)

# %%
canada_df.head()
# Out:
#    C_YEAR C_MNTH C_WDAY C_HOUR C_WTHR C_RSUR  V_TYPE  P_ISEV  P_SAFE
# 0    2011      1      1     10      1      3       1       0       1
# 1    2011      1      1     12      1      5       1       0       0
# 2    2011      1      1     00      7      3       1       0       0
# 3    2011      1      1     17      1      1       1       0       0
# 4    2011      1      1     17      1      1       1       0       1

# %%
group = canada_df.groupby(['C_YEAR', 'C_MNTH', 'C_WDAY', 'C_HOUR', 'C_WTHR', 'C_RSUR'])
group.sum().reset_index().head()
# Out:
#    C_YEAR C_MNTH C_WDAY C_HOUR C_WTHR C_RSUR  V_TYPE  P_ISEV  P_SAFE
# 0    2011      1      1     00      1      1      11       0       2
# 1    2011      1      1     00      1      2       2       0       0
# 2    2011      1      1     00      1      3       1       0       2
# 3    2011      1      1     00      1      5       4       0       0
# 4    2011      1      1     00      1      Q       1       0       1

# %%
df = group['P_ISEV'].sum().reset_index()
df.head()
# Out:
#    C_YEAR C_MNTH C_WDAY C_HOUR C_WTHR C_RSUR  P_ISEV
# 0    2011      1      1     00      1      1       0
# 1    2011      1      1     00      1      2       0
# 2    2011      1      1     00      1      3       0
# 3    2011      1      1     00      1      5       0
# 4    2011      1      1     00      1      Q       0

# %%
df2 = group['P_SAFE'].max().reset_index()
df2.head()
# Out:
#    C_YEAR C_MNTH C_WDAY C_HOUR C_WTHR C_RSUR  P_SAFE
# 0    2011      1      1     00      1      1       1
# 1    2011      1      1     00      1      2       0
# 2    2011      1      1     00      1      3       2
# 3    2011      1      1     00      1      5       0
# 4    2011      1      1     00      1      Q       1

# %%
df3 = group['V_TYPE'].max().reset_index()
df3.head()
# Out:
#    C_YEAR C_MNTH C_WDAY C_HOUR C_WTHR C_RSUR  V_TYPE
# 0    2011      1      1     00      1      1       1
# 1    2011      1      1     00      1      2       1
# 2    2011      1      1     00      1      3       1
# 3    2011      1      1     00      1      5       1
# 4    2011      1      1     00      1      Q       1

# %%
df_merge1 = df.merge(df2, how='inner')
df_merge1.head()
# Out:
#    C_YEAR C_MNTH C_WDAY C_HOUR C_WTHR C_RSUR  P_ISEV  P_SAFE
# 0    2011      1      1     00      1      1       0       1
# 1    2011      1      1     00      1      2       0       0
# 2    2011      1      1     00      1      3       0       2
# 3    2011      1      1     00      1      5       0       0
# 4    2011      1      1     00      1      Q       0       1

# %%
datagrouped = df_merge1.merge(df3, how='inner')
datagrouped.head()
# Out:
#    C_YEAR C_MNTH C_WDAY C_HOUR C_WTHR C_RSUR  P_ISEV  P_SAFE  V_TYPE
# 0    2011      1      1     00      1      1       0       1       1
# 1    2011      1      1     00      1      2       0       0       1
# 2    2011      1      1     00      1      3       0       2       1
# 3    2011      1      1     00      1      5       0       0       1
# 4    2011      1      1     00      1      Q       0       1       1

# %%
datagrouped.rename(columns={'C_YEAR': 'year', 'C_MNTH': 'month', 'C_WDAY': 'day', 'C_HOUR': 'hour', 'C_WTHR': 'weather', 'C_RSUR': 'surface', 'P_ISEV': 'fatality', 'P_SAFE': 'safety_device'}, inplace=True)

# %%
datagrouped.dtypes
# Out:
# year              int64
# month            object
# day              object
# hour             object
# weather          object
# surface          object
# fatality          int64
# safety_device     int64
# V_TYPE            int64
# dtype: object

# %%
datagrouped['surface'] = datagrouped['surface'].replace({'1': 'Normal', '2': 'Wet', '3': 'Snow', '4': 'Snow', '5': 'Icy', '6': 'Sandy', '7': 'Muddy', '8': 'Oil', '9': 'Flooded', 'Q': 'Other', 'U': 'Other', 'X': 'Other'})

# %%
datagrouped.head()
# Out:
#    year month day hour weather surface  fatality  safety_device  V_TYPE
# 0  2011     1   1   00       1  Normal         0              1       1
# 1  2011     1   1   00       1     Wet         0              0       1
# 2  2011     1   1   00       1    Snow         0              2       1
# 3  2011     1   1   00       1     Icy         0              0       1
# 4  2011     1   1   00       1   Other         0              1       1

# %%
onlyfatalities = datagrouped[datagrouped.fatality != 0]

# %%
finaldata = onlyfatalities[onlyfatalities.V_TYPE != 0]

# %%
finaldata.head()
# Out:
#      year month day hour weather surface  fatality  safety_device  V_TYPE
# 23   2011     1   1   03       1   Other         1              1       1
# 47   2011     1   1   06       1     Icy         1              1       1
# 114  2011     1   1   09       4    Snow         1              0       1
# 156  2011     1   1   12       1  Normal         1              2       1
# 234  2011     1   1   16       1  Normal         1              2       1

# %%
finaldata['source'] = 'Canada'
# Out:
# C:\Users\Iam\anaconda\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
renamed = finaldata.reset_index()

# %%
renamed = renamed.drop(columns=['V_TYPE'])

# %%
renamed.head()
# Out:
#    index  year month day hour weather surface  fatality  safety_device  source
# 0     23  2011     1   1   03       1   Other         1              1  Canada
# 1     47  2011     1   1   06       1     Icy         1              1  Canada
# 2    114  2011     1   1   09       4    Snow         1              0  Canada
# 3    156  2011     1   1   12       1  Normal         1              2  Canada
# 4    234  2011     1   1   16       1  Normal         1              2  Canada

# %%
renamed.rename(columns={'index':'accident_id'}, inplace=True)

# %%
renamed.head()
# Out:
#    accident_id  year month day hour weather surface  fatality  safety_device  \
# 0           23  2011     1   1   03       1   Other         1              1
# 1           47  2011     1   1   06       1     Icy         1              1
# 2          114  2011     1   1   09       4    Snow         1              0
# 3          156  2011     1   1   12       1  Normal         1              2
# 4          234  2011     1   1   16       1  Normal         1              2
#
#    source
# 0  Canada
# 1  Canada
# 2  Canada
# 3  Canada
# 4  Canada

# %%
renamed['month'] = renamed['month'].replace({'UU': 0, 'XX': 0})

# %%
renamed['day'] = renamed['day'].replace({'U': 0, 'X': 0})

# %%
renamed.head()
# Out:
#    accident_id  year month day hour weather surface  fatality  safety_device  \
# 0           23  2011     1   1   03       1   Other         1              1
# 1           47  2011     1   1   06       1     Icy         1              1
# 2          114  2011     1   1   09       4    Snow         1              0
# 3          156  2011     1   1   12       1  Normal         1              2
# 4          234  2011     1   1   16       1  Normal         1              2
#
#    source
# 0  Canada
# 1  Canada
# 2  Canada
# 3  Canada
# 4  Canada

# %%
renamed['weather'].replace({'1': 'Clear', '2': 'Cloudy', '3': 'Rain', '4': 'Snow/Hail', '5': 'Snow/Hail', '6': 'Fog/Smoke', '7': 'Strong Wind', 'Q': 'Other', 'U': 'Other', 'X': 'Other'}, inplace=True)

# %%
renamed.head()
# Out:
#    accident_id  year month day hour    weather surface  fatality  \
# 0           23  2011     1   1   03      Clear   Other         1
# 1           47  2011     1   1   06      Clear     Icy         1
# 2          114  2011     1   1   09  Snow/Hail    Snow         1
# 3          156  2011     1   1   12      Clear  Normal         1
# 4          234  2011     1   1   16      Clear  Normal         1
#
#    safety_device  source
# 0              1  Canada
# 1              1  Canada
# 2              0  Canada
# 3              2  Canada
# 4              2  Canada

# %%
renamed['safety_device'].replace({2: 'Not Used', 1: 'Unknown', 0: 'Used'}, inplace=True)

# %%
renamed.head()
# Out:
#    accident_id  year month day hour    weather surface  fatality  \
# 0           23  2011     1   1   03      Clear   Other         1
# 1           47  2011     1   1   06      Clear     Icy         1
# 2          114  2011     1   1   09  Snow/Hail    Snow         1
# 3          156  2011     1   1   12      Clear  Normal         1
# 4          234  2011     1   1   16      Clear  Normal         1
#
#   safety_device  source
# 0       Unknown  Canada
# 1       Unknown  Canada
# 2          Used  Canada
# 3      Not Used  Canada
# 4      Not Used  Canada

# %%
from config import user, password
import pymysql
from sqlalchemy import create_engine
pymysql.install_as_MySQLdb()

# %%
rds_connection_string = user + ":" + password + "@localhost:3306/traffic_etl"
engine = create_engine(f'mysql://{rds_connection_string}')

# %%
# prove that it is working:
engine.table_names()
# Out:
# ['accidents']

# %%
renamed.to_sql(name='accidents', con=engine, if_exists='append', index=False)
